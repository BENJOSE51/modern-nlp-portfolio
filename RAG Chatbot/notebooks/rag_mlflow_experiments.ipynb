# %% [markdown]
# ### Importing packages

# %%
import mlflow
import numpy as np
import pandas as pd
import re

from sentence_transformers import SentenceTransformer
import faiss

# %%
mlflow.set_experiment("RAG-Experiments")
# Out:
# 2026/01/04 20:25:08 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/04 20:25:08 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/04 20:25:08 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/04 20:25:08 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2026/01/04 20:25:09 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2026/01/04 20:25:10 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# 2026/01/04 20:25:11 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/04 20:25:11 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/04 20:25:11 INFO mlflow.tracking.fluent: Experiment with name 'RAG-Experiments' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:C:/Users/benjo/Documents/RAG CHATBOT/notebooks/mlruns/1', creation_time=1767538511207, experiment_id='1', last_update_time=1767538511207, lifecycle_stage='active', name='RAG-Experiments', tags={}>

# %%
df = pd.read_csv("codebasics_faqs.csv",encoding="cp1252")

documents = (
    "Prompt: " + df["prompt"].astype(str) +
    ". Response: " + df["response"].astype(str)
).tolist()

print(f"Loaded {len(documents)} documents")
